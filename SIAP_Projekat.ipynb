# %% [markdown]
# <a href="https://colab.research.google.com/github/Voland24/Videogame-Price-prediction-via-ML/blob/main/SIAP_Projekat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


pd.set_option("display.max_columns", None)
pd.set_option("max_rows", None)

df = pd.read_csv("/content/all_games.csv")

df.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score user_review
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  As most major publishers' development efforts ...          98         7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 3  This is a tale of souls and swords, transcendi...          98         8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9

# %%
df1 = pd.read_csv("/content/Video_Game_Sales_as_of_Jan_2017.csv")

df1.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Rating
# ...

# %%
df.rename(columns = {"name":"Name", "platform":"Platform"}, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18800 entries, 0 to 18799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          18800 non-null  object
#  1   Platform      18800 non-null  object
#  2   release_date  18800 non-null  object
#  3   summary       18686 non-null  object
#  4   meta_score    18800 non-null  int64
#  5   user_review   18800 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 881.4+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17416 entries, 0 to 17415
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             17416 non-null  object
#  1   Platform         17416 non-null  object
#  2   Year_of_Release  17408 non-null  float64
#  3   Genre            17416 non-null  object
#  4   Publisher        17415 non-null  object
#  5   NA_Sales         17416 non-null  float64
#  6   EU_Sales         17416 non-null  float64
#  7   JP_Sales         17416 non-null  float64
#  8   Other_Sales      17416 non-null  float64
#  9   Global_Sales     17416 non-null  float64
#  10  Critic_Score     8336 non-null   float64
#  11  Critic_Count     8336 non-null   float64
#  12  User_Score       7798 non-null   float64
#  13  User_Count       7798 non-null   float64
#  14  Rating           10252 non-null  object
# dtypes: float64(10), object(5)
# memory usage: 2.0+ MB

# %%
print(f"len of first {df[df.columns[0]].count()}")
print(f"len of second {df1[df1.columns[0]].count()}")
# Out:
# len of first 18800
# len of second 17416

# %%
df1['Platform'] = df1['Platform'].replace(['N64','PS', 'PS3', 'DC','X360','Wii',
                                          'XOne','PC','PS2','PS4','GC','X','WiiU',
                                          'GBA','3DS','DS','PSV','PSP'], 
       [' Nintendo 64', ' PlayStation', ' PlayStation 3', ' Dreamcast',
       ' Xbox 360', ' Wii', ' Xbox One', ' PC',
       ' PlayStation 2', ' PlayStation 4', ' GameCube', ' Xbox', ' Wii U',
       ' Game Boy Advance', ' 3DS', ' DS',
       ' PlayStation Vita', ' PSP',])

# %%
df_combined = pd.merge(df, df1, how = 'inner', on=["Name", "Platform"])

# %%
df_combined.head()

# print(f"len of combined {df_combined[df_combined.columns[0]].count()}")
# Out:
#                                    Name        Platform       release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64  November 23, 1998
# 1                   Grand Theft Auto IV   PlayStation 3     April 29, 2008
# 2                           SoulCalibur       Dreamcast  September 8, 1999
# 3                   Grand Theft Auto IV        Xbox 360     April 29, 2008
# 4                    Super Mario Galaxy             Wii  November 12, 2007
#
#                                              summary  meta_score user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 2  This is a tale of souls and swords, transcendi...          98         8.4
# 3  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9
# 4  [Metacritic's 2007 Wii Game of the Year] The u...          97         9.1
#
# ...

# %%
df['Name'].nunique()
# Out:
# 12254

# %%
df1['Name'].nunique()
# Out:
# 12080

# %%
df['Platform'].unique()
# Out:
# array([' Nintendo 64', ' PlayStation', ' PlayStation 3', ' Dreamcast',
#        ' Xbox 360', ' Wii', ' Xbox One', ' PC', ' Switch',
#        ' PlayStation 2', ' PlayStation 4', ' GameCube', ' Xbox', ' Wii U',
#        ' Game Boy Advance', ' 3DS', ' Xbox Series X', ' DS',
#        ' PlayStation Vita', ' PlayStation 5', ' PSP', ' Stadia'],
#       dtype=object)

# %%
df1['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'G', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'X', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df_combined.loc[0]
# Out:
# Name                            The Legend of Zelda: Ocarina of Time
# Platform                                                 Nintendo 64
# release_date                                       November 23, 1998
# summary            As a young boy, Link is tricked by Ganondorf, ...
# meta_score                                                        99
# user_review                                                      9.1
# Year_of_Release                                               1998.0
# Genre                                                         Action
# Publisher                                                   Nintendo
# NA_Sales                                                         4.1
# EU_Sales                                                        1.89
# JP_Sales                                                        1.45
# Other_Sales                                                     0.16
# Global_Sales                                                     7.6
# ...

# %%
import requests, pprint, json
games_arr = []
for i in range(61):
  url = (f'https://steamspy.com/api.php?request=all&page={i}')
  response = requests.get(url)
  payload = response.json()
  games_arr.append(payload)

games_arr = [game_dict[key] for game_dict in games_arr for key in game_dict]

print(games_arr[:10])
# Out:
# [{'appid': 570, 'name': 'Dota 2', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 1596223, 'negative': 333113, 'userscore': 0, 'owners': '200,000,000 .. 500,000,000', 'average_forever': 38179, 'average_2weeks': 1530, 'median_forever': 904, 'median_2weeks': 754, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 470308}, {'appid': 730, 'name': 'Counter-Strike: Global Offensive', 'developer': 'Valve, Hidden Path Entertainment', 'publisher': 'Valve', 'score_rank': '', 'positive': 6129357, 'negative': 805515, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 29163, 'average_2weeks': 864, 'median_forever': 6238, 'median_2weeks': 346, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 1035784}, {'appid': 578080, 'name': 'PUBG: BATTLEGROUNDS', 'developer': 'KRAFTON, Inc.', 'publisher': 'KRAFTON, Inc.', 'score_rank': '', 'positive': 1220042, 'negative': 920249, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_fo
# ...

# %%
print(len(games_arr))
print(games_arr[0])

with open('/content/steamspy_all.json', 'w') as file:
  json.dump(games_arr, file)
# Out:
# 60811
# {'appid': 570, 'name': 'Dota 2', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 1596223, 'negative': 333113, 'userscore': 0, 'owners': '200,000,000 .. 500,000,000', 'average_forever': 38179, 'average_2weeks': 1530, 'median_forever': 904, 'median_2weeks': 754, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 470308}

# %%
df_steam = pd.read_json('/content/steamspy_all.json')

# %%
df_steam.head()
# Out:
#      appid                              name  \
# 0      570                            Dota 2
# 1      730  Counter-Strike: Global Offensive
# 2   578080               PUBG: BATTLEGROUNDS
# 3  1063730                         New World
# 4  1172470                      Apex Legends
#
#                           developer        publisher score_rank  positive  \
# 0                             Valve            Valve              1596223
# 1  Valve, Hidden Path Entertainment            Valve              6129357
# 2                     KRAFTON, Inc.    KRAFTON, Inc.              1220042
# 3                      Amazon Games     Amazon Games               175311
# 4             Respawn Entertainment  Electronic Arts               493199
#
#    negative  userscore                      owners  average_forever  \
# 0    333113          0  200,000,000 .. 500,000,000            38179
# 1    805515          0   50,000,000 .. 100,000,000            29163
# ...

# %%
df_combined_steam = pd.merge(df_combined, df_steam, how = 'inner', left_on = 'Name', right_on = 'name')

df_combined_steam.head()

print(f"len of combined {df_combined_steam[df_combined_steam.columns[0]].count()}")
# Out:
# len of combined 1021

# %%
ser = set(df['Name']) & set(df_steam['name'])
print(len(ser))
# Out:
# 3501
