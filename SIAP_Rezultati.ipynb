# %%
import pandas as pd
import numpy as np

#pd.set_option("max_rows", None)

df_newer_games = pd.read_csv('/content/Video_Games_newer_all_data.csv')
df_games_igdb = pd.read_json('/content/igdb_games_data.json')
df_video_ids = pd.read_json('/content/igdb_games_video_data.json')

rawg_json_data_slug = pd.read_json('/content/rawg_games_details_data_1.json')
rawg_json_data_self_slug = pd.read_json('/content/rawg_games_details_data_2.json')

len(df_newer_games)
# Out:
# 16719

# %%
df_newer_games.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
rawg_json_data_slug.head(10)
# Out:
#        id                      slug                       name  \
# 0   25057                wii-sports                 Wii Sports
# 1   25080          super-mario-bros          Super Mario Bros.
# 2   24761            mario-kart-wii             Mario Kart Wii
# 3   26002         wii-sports-resort          Wii Sports Resort
# 4   24933      new-super-mario-bros      New Super Mario Bros.
# 5   24901                  wii-play                   Wii Play
# 6   24493  new-super-mario-bros-wii  New Super Mario Bros. Wii
# 7  286110                 duck-hunt                  Duck Hunt
# 8   23943             mario-kart-ds              Mario Kart DS
# 9   25482                   wii-fit                    Wii Fit
#
#                name_original  \
# 0                 Wii Sports
# 1          Super Mario Bros.
# 2             Mario Kart Wii
# 3          Wii Sports Resort
# 4      New Super Mario Bros.
# 5                   Wii Play
# 6  New Super Mario Bros. Wii
# ...

# %%
rawg_json_data_self_slug.head(10)
# Out:
#         id                                         slug  \
# 0   5731.0                                       tetris
# 1   3498.0                           grand-theft-auto-v
# 2  24934.0  brain-age-train-your-brain-in-minutes-a-day
# 3      NaN                            cod-black-ops-iii
# 4      NaN                             cod-black-ops-ii
# 5    432.0                         grand-theft-auto-iii
# 6   4459.0                          grand-theft-auto-iv
# 7  52939.0                            final-fantasy-vii
# 8   5679.0                   the-elder-scrolls-v-skyrim
# 9      NaN                            ea-sports-fifa-16
#
#                                             name  \
# 0                                         TETRIS
# 1                             Grand Theft Auto V
# 2  Brain Age: Train Your Brain in Minutes a Day!
# 3                                            NaN
# 4                                            NaN
# ...

# %%
frames = [rawg_json_data_slug, rawg_json_data_self_slug]
df_rawg_combined = pd.concat(frames)

# %%
df_rawg_combined.head(10)
# Out:
#          id                      slug                       name  \
# 0   25057.0                wii-sports                 Wii Sports
# 1   25080.0          super-mario-bros          Super Mario Bros.
# 2   24761.0            mario-kart-wii             Mario Kart Wii
# 3   26002.0         wii-sports-resort          Wii Sports Resort
# 4   24933.0      new-super-mario-bros      New Super Mario Bros.
# 5   24901.0                  wii-play                   Wii Play
# 6   24493.0  new-super-mario-bros-wii  New Super Mario Bros. Wii
# 7  286110.0                 duck-hunt                  Duck Hunt
# 8   23943.0             mario-kart-ds              Mario Kart DS
# 9   25482.0                   wii-fit                    Wii Fit
#
#                name_original  \
# 0                 Wii Sports
# 1          Super Mario Bros.
# 2             Mario Kart Wii
# 3          Wii Sports Resort
# 4      New Super Mario Bros.
# 5                   Wii Play
# 6  New Super Mario Bros. Wii
# ...

# %%
print(len(df_rawg_combined))
# Out:
# 7644

# %%
df_rawg_combined.isna().sum()
# Out:
# id                              332
# slug                              0
# name                            332
# name_original                   332
# description                     332
# metacritic                     5598
# metacritic_platforms            332
# released                        674
# tba                             332
# updated                         332
# background_image               1441
# background_image_additional    1601
# website                         332
# rating                          332
# rating_top                      332
# ratings                         332
# reactions                      4832
# added                           332
# added_by_status                 857
# playtime                        332
# screenshots_count               332
# movies_count                    332
# creators_count                  332
# achievements_count              332
# parent_achievements_count       332
# reddit_url                      332
# ...

# %%
#df.drop(['A'], axis=1)

df_rawg_combined.drop(['metacritic'], axis=1, inplace = True)
df_rawg_combined.drop(['background_image'], axis=1, inplace = True)
df_rawg_combined.drop(['background_image_additional'], axis=1, inplace = True)
df_rawg_combined.drop(['reactions'], axis=1, inplace = True)
df_rawg_combined.drop(['user_game'], axis=1, inplace = True)
df_rawg_combined.drop(['esrb_rating'], axis=1, inplace = True)
df_rawg_combined.drop(['clip'], axis=1, inplace = True)
df_rawg_combined.drop(['community_rating'], axis=1, inplace = True)
df_rawg_combined.drop(['redirect'], axis=1, inplace = True)

# %%
df_rawg_combined.isna().sum()
# Out:
# id                           332
# slug                           0
# name                         332
# name_original                332
# description                  332
# metacritic_platforms         332
# released                     674
# tba                          332
# updated                      332
# website                      332
# rating                       332
# rating_top                   332
# ratings                      332
# added                        332
# added_by_status              857
# playtime                     332
# screenshots_count            332
# movies_count                 332
# creators_count               332
# achievements_count           332
# parent_achievements_count    332
# reddit_url                   332
# reddit_name                  332
# reddit_description           332
# reddit_logo                  332
# reddit_count                 332
# twitch_count                 332
# youtube_count                332
# ...

# %%
df_rawg_combined = df_rawg_combined.dropna()

# %%
len(df_rawg_combined)
# Out:
# 6525

# %%
df_newer_games['Name'].nunique()
# Out:
# 11562

# %%
df_newer_games.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df_newer_games.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df_newer_games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
len(df_games_igdb)
# Out:
# 8833

# %%
df_games_igdb['name'].nunique()
# Out:
# 7505

# %%
df_games_igdb.describe()
# Out:
#                  id  aggregated_rating  aggregated_rating_count  total_rating  \
# count    8833.00000        3676.000000              3676.000000   4719.000000
# mean    50387.04619          67.982551                 4.275571     68.231366
# std     65671.35753          16.100312                 4.389283     14.388640
# min         3.00000           0.000000                 0.000000      0.000000
# 25%      5239.00000          60.000000                 2.000000     60.000000
# 50%     20456.00000          70.000000                 3.000000     70.391685
# 75%     66733.00000          80.000000                 5.000000     78.968056
# max    238609.00000         100.000000                43.000000    100.000000
#
#        total_rating_count       hypes
# count         4719.000000  329.000000
# mean            54.276542    8.009119
# std            176.462726   22.373150
# min              0.000000    1.000000
# 25%              3.000000    1.000000
# ...

# %%
df_games_igdb.isna().sum()
# Out:
# id                            0
# game_modes                 2360
# genres                     1012
# name                          0
# player_perspectives        3240
# summary                     767
# themes                     2814
# videos                     5431
# aggregated_rating          5157
# aggregated_rating_count    5157
# total_rating               4114
# total_rating_count         4114
# storyline                  7387
# hypes                      8504
# dtype: int64

# %%
df_games_igdb.head()
# Out:
#        id game_modes genres    name player_perspectives  \
# 0  203104        [1]    [9]  Tetris                 [4]
# 1  203117        [1]    [9]  Tetris                 [4]
# 2  131503        [1]    [9]  Tetris                 [4]
# 3  203110        [1]    [9]  Tetris                 [4]
# 4  203109        [1]    [9]  Tetris                 [4]
#
#                                              summary themes   videos  \
# 0  Tetris for Famicom is a port of the Japanese h...    NaN      NaN
# 1  Tetris is a licensed Tetris game for Fifth-Gen...    NaN      NaN
# 2  A tile-matching puzzle video game. The goal is...   [40]  [35504]
# 3  Tetris for Fujitsu OASYS series word processor...    NaN      NaN
# 4  Tetris is a game for the Sharp Wizard or Elect...    NaN      NaN
#
#    aggregated_rating  aggregated_rating_count  total_rating  \
# 0                NaN                      NaN           NaN
# 1                NaN                      NaN           NaN
# ...

# %%
len(df_video_ids)
# Out:
# 5135

# %%
df_video_ids['name'].nunique()
# Out:
# 343

# %%
df_video_ids.describe()
# Out:
#                  id           game
# count   5135.000000    5135.000000
# mean   27561.694839   25431.103992
# std    24277.609255   44793.995400
# min       12.000000       3.000000
# 25%     6106.000000    2686.000000
# 50%    19428.000000    7390.000000
# 75%    44764.500000   21015.000000
# max    84524.000000  238609.000000

# %%
df_video_ids.isna().sum()
# Out:
# id           0
# game         0
# name        35
# video_id     0
# checksum     0
# dtype: int64

# %%
df_video_ids.head()
# Out:
#       id    game            name     video_id  \
# 0  35504  131503  Gameplay Video  KoCFToFstSY
# 1  49958  150031  Gameplay Video  MsGO5lobqAk
# 2   1420    1020  Gameplay video  N-xHcvug3WI
# 3  12259    2345         Trailer  3Bx9WtQ5EMg
# 4  20256    1068         Trailer  HU80R7jGanE
#
#                                checksum
# 0  cfebfc9d-7c09-cf8d-cf93-aeacb0ad8417
# 1  cc8cc320-af31-c2a7-4cc7-b3b00fb7cfcb
# 2  78730f2e-fdfd-fc29-46c7-2a9e00c0cadf
# 3  2c737ba5-0836-1717-a9e5-1b7b13611b25
# 4  ad74f145-73d2-ac03-eeda-83df3cac9732

# %%
df_games_igdb = df_games_igdb.drop_duplicates(subset=["name"], keep='first')
len(df_games_igdb)
# Out:
# 7505

# %%
df_new_combined = pd.merge(df_newer_games, df_games_igdb, how = 'inner', left_on = "Name", right_on = "name")

df_new_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11314 entries, 0 to 11313
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     11314 non-null  object
#  1   Platform                 11314 non-null  object
#  2   Year_of_Release          11110 non-null  float64
#  3   Genre                    11314 non-null  object
#  4   Publisher                11299 non-null  object
#  5   NA_Sales                 11314 non-null  float64
#  6   EU_Sales                 11314 non-null  float64
#  7   JP_Sales                 11314 non-null  float64
#  8   Other_Sales              11314 non-null  float64
#  9   Global_Sales             11314 non-null  float64
#  10  Critic_Score             6516 non-null   float64
#  11  Critic_Count             6516 non-null   float64
#  12  User_Score               7902 non-null   object
# ...

# %%
len(df_new_combined)
# Out:
# 11314

# %%
df_new_combined.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     11110.000000  11314.000000  11314.000000  11314.000000
# mean       2006.148065      0.270353      0.141908      0.063767
# std           5.946618      0.703543      0.405957      0.252664
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.020000      0.000000      0.000000
# 50%        2007.000000      0.090000      0.030000      0.000000
# 75%        2010.000000      0.250000      0.110000      0.020000
# max        2020.000000     26.930000      9.090000      5.330000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count  \
# count  11314.000000  11314.000000   6516.000000   6516.000000   6019.000000
# mean       0.047165      0.523503     68.724217     25.982198    147.889517
# std        0.181982      1.254269     14.052546     18.597617    531.912144
# ...

# %%
df_new_combined.head()
# Out:
#             Name Platform  Year_of_Release    Genre Publisher  NA_Sales  \
# 0         Tetris       GB           1989.0   Puzzle  Nintendo     23.20
# 1         Tetris      NES           1988.0   Puzzle  Nintendo      2.97
# 2      Duck Hunt      NES           1984.0  Shooter  Nintendo     26.93
# 3  Mario Kart DS       DS           2005.0   Racing  Nintendo      9.71
# 4        Wii Fit      Wii           2007.0   Sports  Nintendo      8.92
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  ...  player_perspectives  \
# 0      2.26      4.22         0.58         30.26  ...                  [4]
# 1      0.69      1.81         0.11          5.58  ...                  [4]
# 2      0.63      0.28         0.47         28.31  ...                  [1]
# 3      7.47      4.13         1.90         23.21  ...                  [2]
# 4      8.03      3.60         2.15         22.70  ...               [1, 2]
#
#                                              summary    themes  \
# ...

# %%
df_new_combined.isna().sum()
# Out:
# Name                           0
# Platform                       0
# Year_of_Release              204
# Genre                          0
# Publisher                     15
# NA_Sales                       0
# EU_Sales                       0
# JP_Sales                       0
# Other_Sales                    0
# Global_Sales                   0
# Critic_Score                4798
# Critic_Count                4798
# User_Score                  3412
# User_Count                  5295
# Developer                   3352
# Rating                      3465
# id                             0
# game_modes                  2563
# genres                      1072
# name                           0
# player_perspectives         3719
# summary                      833
# themes                      3504
# videos                      6566
# aggregated_rating           5581
# aggregated_rating_count     5581
# total_rating                4345
# total_rating_count          4345
# ...

# %%
df_new_combined.drop('hypes', axis=1, inplace = True)
df_new_combined.drop('storyline', axis=1, inplace = True)
df_new_combined.drop('videos', axis=1, inplace = True)
df_new_combined.drop('name', axis=1, inplace = True)

# %%
mask = df_newer_games.notnull()
  
tmp = df_newer_games.where(mask).dropna()
tmp.loc[0]
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6825 non-null   object
#  1   Platform         6825 non-null   object
#  2   Year_of_Release  6825 non-null   float64
#  3   Genre            6825 non-null   object
#  4   Publisher        6825 non-null   object
#  5   NA_Sales         6825 non-null   float64
#  6   EU_Sales         6825 non-null   float64
#  7   JP_Sales         6825 non-null   float64
#  8   Other_Sales      6825 non-null   float64
#  9   Global_Sales     6825 non-null   float64
#  10  Critic_Score     6825 non-null   float64
#  11  Critic_Count     6825 non-null   float64
#  12  User_Score       6825 non-null   object
#  13  User_Count       6825 non-null   float64
#  14  Developer        6825 non-null   object
#  15  Rating           6825 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6825 non-null   object
#  1   Platform         6825 non-null   object
#  2   Year_of_Release  6825 non-null   float64
#  3   Genre            6825 non-null   object
#  4   Publisher        6825 non-null   object
#  5   NA_Sales         6825 non-null   float64
#  6   EU_Sales         6825 non-null   float64
#  7   JP_Sales         6825 non-null   float64
#  8   Other_Sales      6825 non-null   float64
#  9   Global_Sales     6825 non-null   float64
#  10  Critic_Score     6825 non-null   float64
#  11  Critic_Count     6825 non-null   float64
#  12  User_Score       6825 non-null   object
#  13  User_Count       6825 non-null   float64
#  14  Developer        6825 non-null   object
#  15  Rating           6825 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
tmp.drop(["Name"], axis = 1, inplace = True)
tmp["User_Score"] = tmp["User_Score"].astype(float)

tmp['Platform'] = tmp['Platform'].astype('category').cat.codes
tmp['Genre'] = tmp['Genre'].astype('category').cat.codes
tmp['Publisher'] = tmp['Publisher'].astype('category').cat.codes
tmp['Developer'] = tmp['Developer'].astype('category').cat.codes
tmp['Rating'] = tmp['Rating'].astype('category').cat.codes

tmp['User_Score'] = tmp['User_Score'].apply(np.ceil)
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Platform         6825 non-null   int8
#  1   Year_of_Release  6825 non-null   float64
#  2   Genre            6825 non-null   int8
#  3   Publisher        6825 non-null   int16
#  4   NA_Sales         6825 non-null   float64
#  5   EU_Sales         6825 non-null   float64
#  6   JP_Sales         6825 non-null   float64
#  7   Other_Sales      6825 non-null   float64
#  8   Global_Sales     6825 non-null   float64
#  9   Critic_Score     6825 non-null   float64
#  10  Critic_Count     6825 non-null   float64
#  11  User_Score       6825 non-null   float64
#  12  User_Count       6825 non-null   float64
#  13  Developer        6825 non-null   int16
#  14  Rating           6825 non-null   int8
# dtypes: float64(10), int16(2), int8(3)
# memory usage: 891.2 KB

# %%
tmp.head()
# Out:
#    Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0        12           2006.0     10        160     41.36     28.96      3.77
# 2        12           2008.0      6        160     15.68     12.76      3.79
# 3        12           2009.0     10        160     15.61     10.93      3.28
# 6         2           2006.0      4        160     11.28      9.14      6.50
# 7        12           2006.0      3        160     13.96      9.18      2.93
#
#    Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# 0         8.45         82.53          76.0          51.0         8.0
# 2         3.29         35.52          82.0          73.0         9.0
# 3         2.95         32.77          80.0          73.0         8.0
# 6         2.88         29.80          89.0          65.0         9.0
# 7         2.84         28.92          58.0          41.0         7.0
#
#    User_Count  Developer  Rating
# 0       322.0        771       1
# ...

# %%
tmp.tail()
# Out:
#        Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 16667         3           2001.0      0        158      0.01      0.00
# 16677         3           2002.0      2        146      0.01      0.00
# 16696         5           2014.0      0        123      0.00      0.01
# 16700         5           2011.0      8         53      0.01      0.00
# 16706         5           2011.0     11        240      0.00      0.01
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 16667       0.0          0.0          0.01          46.0           4.0
# 16677       0.0          0.0          0.01          81.0          12.0
# 16696       0.0          0.0          0.01          80.0          20.0
# 16700       0.0          0.0          0.01          61.0          12.0
# 16706       0.0          0.0          0.01          60.0          12.0
#
#        User_Score  User_Count  Developer  Rating
# 16667         3.0        21.0        411       1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor

training, test = train_test_split(tmp, test_size = 0.25, random_state = 32)

features = training.drop(['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'], axis = 1).columns
print(features)
# Out:
# Index(['Platform', 'Year_of_Release', 'Genre', 'Publisher', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
training_features, training_labels = training[features], training['NA_Sales']
test_features, test_labels = test[features], test['NA_Sales']

pipeline = Pipeline([('scaler', MinMaxScaler()), ('regressor', XGBRegressor())])
pipeline.fit(training_features, training_labels)

r2 = pipeline.score(test_features, test_labels)
print(f'Score {r2}')
# Out:
# [17:45:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Score 0.39844316630438426

# %%
from sklearn import svm
tmp['User_Score'] = tmp['User_Score'].astype(float)
tmp['User_Score'] = np.where(tmp['User_Score'] <=3.5, 0, tmp['User_Score'])
tmp['User_Score'] = np.where((3.5 < tmp['User_Score']) & ( tmp['User_Score'] <=7.5), 1 ,tmp['User_Score'])
tmp['User_Score'] = np.where(7.5 < tmp['User_Score'] , 2 ,tmp['User_Score'])
tmp['User_Score'] = tmp['User_Score'].astype('category').cat.codes
training, test = train_test_split(tmp, test_size = 0.25, random_state = 32)
features = training.drop(['User_Score'], axis = 1).columns

training_features, training_labels = training[features], training['User_Score']
test_features, test_labels = test[features], test['User_Score']

training_features.head()
# Out:
#        Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 13291         6           1998.0      4         59      0.03      0.02
# 2420          6           2001.0      6         62      0.48      0.33
# 469           9           2013.0     10         61      0.61      1.85
# 9229         14           2007.0      9        237      0.11      0.02
# 13817         5           2011.0     11        240      0.00      0.03
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 13291      0.00         0.00          0.05          69.0           8.0
# 2420       0.00         0.06          0.86          53.0           4.0
# 469        0.11         0.44          3.01          87.0          26.0
# 9229       0.00         0.01          0.14          72.0          24.0
# 13817      0.00         0.01          0.04          68.0          19.0
#
#        User_Count  Developer  Rating
# 13291         4.0       1163       1
# ...

# %%
training_labels.head()
# Out:
# 13291    2
# 2420     1
# 469      1
# 9229     2
# 13817    1
# Name: User_Score, dtype: int8

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5118 entries, 13291 to 4636
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Platform         5118 non-null   int8
#  1   Year_of_Release  5118 non-null   float64
#  2   Genre            5118 non-null   int8
#  3   Publisher        5118 non-null   int16
#  4   NA_Sales         5118 non-null   float64
#  5   EU_Sales         5118 non-null   float64
#  6   JP_Sales         5118 non-null   float64
#  7   Other_Sales      5118 non-null   float64
#  8   Global_Sales     5118 non-null   float64
#  9   Critic_Score     5118 non-null   float64
#  10  Critic_Count     5118 non-null   float64
#  11  User_Score       5118 non-null   int8
#  12  User_Count       5118 non-null   float64
#  13  Developer        5118 non-null   int16
#  14  Rating           5118 non-null   int8
# dtypes: float64(9), int16(2), int8(4)
# memory usage: 439.8 KB

# %%
from sklearn import preprocessing
clf_svm = svm.SVC(kernel='rbf')
scaler = preprocessing.StandardScaler().fit(training[features])
features_nomalizovane = scaler.transform(training[features])
clf_svm.fit(features_nomalizovane, training_labels)

clf_svm.predict(scaler.transform([test[features].iloc[0]]))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([1], dtype=int8)

# %%
clf_svm.score(scaler.transform(test[features]), test_labels)
# Out:
# 0.7516110134739309

# %%
from sklearn.metrics import f1_score

svm_predictions = clf_svm.predict(scaler.transform(test[features]))
f1_score(test_labels, svm_predictions, average=None)
# Out:
# array([0.        , 0.625     , 0.82384106])

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels,svm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.67      0.58      0.63       599
#            2       0.79      0.86      0.82      1079
#
#     accuracy                           0.75      1707
#    macro avg       0.49      0.48      0.48      1707
# weighted avg       0.73      0.75      0.74      1707
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#df_rawg_combined
#tmp
mask = df_new_combined.notnull()
tmp_new = df_new_combined.where(mask).dropna()
#po name


df_new_combined_rawg = pd.merge(df_rawg_combined, tmp_new, how = 'inner', left_on = "name_original", right_on = "Name")

# %%
df_new_combined_rawg.head(5)
# Out:
#       id_x                          slug                           name  \
# 0  23943.0                 mario-kart-ds                  Mario Kart DS
# 1  25482.0                       wii-fit                        Wii Fit
# 2    416.0  grand-theft-auto-san-andreas  Grand Theft Auto: San Andreas
# 3    416.0  grand-theft-auto-san-andreas  Grand Theft Auto: San Andreas
# 4    416.0  grand-theft-auto-san-andreas  Grand Theft Auto: San Andreas
#
#                    name_original  \
# 0                  Mario Kart DS
# 1                        Wii Fit
# 2  Grand Theft Auto: San Andreas
# 3  Grand Theft Auto: San Andreas
# 4  Grand Theft Auto: San Andreas
#
#                                          description  \
# 0  <p>Race along with Mario and his friends in fi...
# 1  <ul>\n<li>\n<p>Control on-screen action with y...
# 2  <p>Grand Theft Auto - San Andreas is the seven...
# 3  <p>Grand Theft Auto - San Andreas is the seven...
# 4  <p>Grand Theft Auto - San Andreas is the seven...
#
# ...

# %%
print(len(df_new_combined_rawg))
# Out:
# 2235

# %%
print(len(rawg_json_data_self_slug))
# Out:
# 1774

# %%
#df_newer_games df_rawg_combined
df = pd.merge(df_newer_games, df_rawg_combined, how = 'inner', left_on = "Name", right_on = "name")

# %%
df.head(5)
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 2  Super Mario Bros.       GB           1999.0  Platform  Nintendo      3.40
# 3     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
# 4  Wii Sports Resort      Wii           2009.0    Sports  Nintendo     15.61
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  ...  saturated_color  \
# 0     28.96      3.77         8.45         82.53  ...           0f0f0f
# 1      3.58      6.81         0.77         40.24  ...           0f0f0f
# 2      1.30      0.15         0.22          5.07  ...           0f0f0f
# 3     12.76      3.79         3.29         35.52  ...           0f0f0f
# 4     10.93      3.28         2.95         32.77  ...           0f0f0f
#
#    dominant_color                                   parent_platforms  \
# ...

# %%
print(len(df))
# Out:
# 8897

# %%
df_newer_games.isna().sum()
df_newer_games.drop(["Critic_Score"], axis = 1, inplace = True)
df_newer_games.drop(["Critic_Count"], axis = 1, inplace = True)
df_newer_games.drop(["User_Score"], axis = 1, inplace = True)
df_newer_games.drop(["User_Count"], axis = 1, inplace = True)
df_newer_games.drop(["Developer"], axis = 1, inplace = True)
df_newer_games.drop(["Rating"], axis = 1, inplace = True)

# %%
print(len(df_newer_games))
# Out:
# 16719

# %%
df = pd.merge(df_newer_games, df_rawg_combined, how = 'inner', left_on = "Name", right_on = "name")

# %%
len(df)
# Out:
# 8897

# %%
df = df.dropna()

# %%
len(df.columns)
# Out:
# 57

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'id', 'slug',
#        'name', 'name_original', 'description', 'metacritic_platforms',
#        'released', 'tba', 'updated', 'website', 'rating', 'rating_top',
#        'ratings', 'added', 'added_by_status', 'playtime', 'screenshots_count',
#        'movies_count', 'creators_count', 'achievements_count',
#        'parent_achievements_count', 'reddit_url', 'reddit_name',
#        'reddit_description', 'reddit_logo', 'reddit_count', 'twitch_count',
#        'youtube_count', 'reviews_text_count', 'ratings_count',
#        'suggestions_count', 'alternative_names', 'metacritic_url',
#        'parents_count', 'additions_count', 'game_series_count',
#        'reviews_count', 'saturated_color', 'dominant_color',
#        'parent_platforms', 'platforms', 'stores', 'developers', 'genres',
#        'tags', 'publishers', 'description_raw'],
# ...

# %%
print(df['name'].nunique())
# Out:
# 5382

# %%
print(df['Name'].nunique())
# Out:
# 5382

# %%
df.to_json('/content/df_new_combined.json')
